# %% [markdown]
# # Rosalind: REVC

# %% [markdown]
# ### Complementing a Strand of DNA

# %% [markdown]
# n DNA strings, symbols 'A' and 'T' are complements of each other, as are 'C' and 'G'.
#
# The reverse complement of a DNA string s
#  is the string sc
#  formed by reversing the symbols of s
# , then taking the complement of each symbol (e.g., the reverse complement of "GTCA" is "TGAC").
#
# Given: A DNA string s
#  of length at most 1000 bp.
#
# Return: The reverse complement sc
#  of s
# .

# %%
# sample dataset:
s = 'AAAACCCGGT'
# sample output: ACCGGGTTTT

# %% [markdown]
# reversing (like tin challenge) + adding different base with if

# %%
s = 'AAAACCCGGT'
result = ""
for base in s:
    result = base + result
print(result)
# Out:
# TGGCCCAAAA

# %%
base_seperate = list(result)
print(base_seperate)
# Out:
# ['T', 'G', 'G', 'C', 'C', 'C', 'A', 'A', 'A', 'A']

# %%
for base in base_seperate: 
    print(base)
    if result == 'T': 
        print('A')
    elif result == 'A':
        print('T')
    elif result == 'G':
        print('C')
    elif result == 'C':
        print('G')
# Out:
# T
# G
# G
# C
# C
# C
# A
# A
# A
# A

# %%
for base in base_seperate: 
    if base == 'T': 
        print('A')
    elif base == 'A':
        print('T')
    elif base == 'G':
        print('C')
    elif base == 'C':
        print('G')
# Out:
# A
# C
# C
# G
# G
# G
# T
# T
# T
# T

# %%
for base in base_seperate: 
    if base == 'T': 
        print('A')
    elif base == 'A':
        print('T')
    elif base == 'G':
        print('C')
    else:
        print('G')
# Out:
# A
# C
# C
# G
# G
# G
# T
# T
# T
# T

# %%
s = 'AAAACCCGGT'
result = ""
for base in s:
    result = base + result
print(result)

base_seperate = list(result)
print(base_seperate)

# new list for additions

addition =[]

for base in base_seperate: 
    if base == 'T': 
        addition.append('A')
    elif base == 'A':
        addition.append('T')
    elif base == 'G':
        addition.append('C')
    elif base == 'C':
        addition.append('G')

print(addition)
# Out:
# TGGCCCAAAA
# ['T', 'G', 'G', 'C', 'C', 'C', 'A', 'A', 'A', 'A']
# ['A', 'C', 'C', 'G', 'G', 'G', 'T', 'T', 'T', 'T']

# %%
print(''.join(['T', 'G', 'G', 'C', 'C', 'C', 'A', 'A', 'A', 'A']))
# Out:
# TGGCCCAAAA
