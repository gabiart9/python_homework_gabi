# %% [markdown]
# # Rosalind INI 4

# %% [markdown]
# ## -> conditions and loops

# %%
# real problem with dataset

a = 4875
b = 9157
result = 0 


for n in range (a, b+1): 
    if n % 2 == 1: 
        result = result + n
print(result)
# Out:
# 15028272

# %% [markdown]
# = correct
