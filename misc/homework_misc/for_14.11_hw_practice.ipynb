# %% [markdown]
# # 9) conditioals - carpentries

# %%
mass = 3.54
if mass > 3.0:
    print(mass, 'is large')

mass = 2.07
if mass > 3.0:
    print (mass, 'is large')
# Out:
# 3.54 is large

# %%
mass = 3.54
if mass > 3.0:
    print(mass, 'is large')

mass = 2.07
if mass > 3.0:
    print (mass, 'is large')
else:
    print (mass, 'is tiny')
# Out:
# 3.54 is large
# 2.07 is tiny

# %%
masses = [3.54, 2.07, 9.22, 1.86, 1.71]
for m in masses:
    if m > 3.0:
        print(m, 'is large')
# Out:
# 3.54 is large
# 9.22 is large

# %%
masses = [3.54, 2.07, 9.22, 1.86, 1.71]
for m in masses:
    if m > 3.0:
        print(m, 'is large')
    else:
        print(m, 'is small')
# Out:
# 3.54 is large
# 2.07 is small
# 9.22 is large
# 1.86 is small
# 1.71 is small

# %%
masses = [3.54, 2.07, 9.22, 1.86, 1.71]
for m in masses:
    if m > 9.0:
        print(m, 'is HUGE')
    elif m > 3.0:
        print(m, 'is large')
    else:
        print(m, 'is small')
# Out:
# 3.54 is large
# 2.07 is small
# 9.22 is HUGE
# 1.86 is small
# 1.71 is small

# %%
grade = 85
if grade >= 90:
    print('grade is A')
elif grade >= 80:
    print('grade is B')
elif grade >= 70:
    print('grade is C')
# Out:
# grade is B

# %% [markdown]
# Python steps through the branches of the conditional in order, testing each in turn.
# ordering matters!!!
# Does not automatically go back and re-evaluate if values change.

# %%
velocity = 10.0
if velocity > 20.0:
    print('moving too fast')
else:
    print('adjusting velocity')
    velocity = 50.0
# Out:
# adjusting velocity

# %% [markdown]
# use conditionals in a loop to “evolve” the values of variables.

# %%
velocity = 10.0
for i in range(5): # execute the loop 5 times
    print(i, ':', velocity)
    if velocity > 20.0:
        print('moving too fast')
        velocity = velocity - 5.0
    else:
        print('moving too slow')
        velocity = velocity + 10.0
print('final velocity:', velocity)
# Out:
# 0 : 10.0
# moving too slow
# 1 : 20.0
# moving too slow
# 2 : 30.0
# moving too fast
# 3 : 25.0
# moving too fast
# 4 : 20.0
# moving too slow
# final velocity: 30.0

# %% [markdown]
# ## callout

# %%
mass     = [ 3.54,  2.07,  9.22,  1.86,  1.71]
velocity = [10.00, 20.00, 30.00, 25.00, 20.00]

i = 0
for i in range(5):
    if mass[i] > 5 and velocity[i] > 20:
        print("Fast heavy object.  Duck!")
    elif mass[i] > 2 and mass[i] <= 5 and velocity[i] <= 20:
        print("Normal traffic")
    elif mass[i] <= 2 and velocity[i] <= 20:
        print("Slow light object.  Ignore it")
    else:
        print("Whoa!  Something is up with the data.  Check it")
# Out:
# Normal traffic
# Normal traffic
# Fast heavy object.  Duck!
# Whoa!  Something is up with the data.  Check it
# Slow light object.  Ignore it

# %% [markdown]
# ## challenges:

# %% [markdown]
# ### Tracing Execution

# %%
pressure = 71.9
if pressure > 50.0:
    pressure = 25.0
elif pressure <= 50.0:
    pressure = 0.0
print(pressure)
# Out:
# 25.0

# %% [markdown]
# ### trimming values
# fill in blans that new list contains:
# - 0 where orginally values were negative
# - 1 where originally positive

# %%
original = [-1.5, 0.2, 0.4, 0.0, -1.3, 0.4]
result = []
for value in original:
    if value < 0:
        result.append(0)
    else:
        result.append(1)
print(result)
# Out:
# [0, 1, 1, 1, 0, 1]

# %% [markdown]
# ### initializing

# %%
values = [...some test data...]
smallest, largest = None, None
for v in values:
    if ____:
        smallest, largest = v, v
    ____:
        smallest = min(____, v)
        largest = max(____, v)
print(smallest, largest)

# %% [markdown]
# # HÄÄÄÄ ????????
