# %% [markdown]
# # SUBS rosalind

# %%
s_sample = 'AUGCUUCAGAAAGGUCUUACG'
t_sample = 'ATAT'
# s[j:k]
# j = j-1
# s[1:5] -> 'UGCU' instead of 2:5 j-1 for this output in python

# %%
for string in DNA:
    if t_sample == s_sample:
        print

# %%
s_sample1 = 'GATATATGCATATACTT'
t_sample1 = 'ATAT'

positions = []

for i in range(len(s_sample1) - len(t_sample1) + 1): # +1 or last base would be gnored in s string
    if s_sample1[i:i+len(t_sample1)] == t:
        positions.append(i + 1)   # 1-based index in python vs 0 based in rosalind

print(positions)
# Out:
# [2, 4, 10]

# %%
# real problem:
s = '...'
t = 'TCTAGCTTC'

positions = []

for i in range(len(s) - len(t) + 1): 
    if s[i:i+len(t)] == t:
        positions.append(i + 1)  

print(positions)
# Out:
# [2, 47, 124, 131, 149, 180, 220, 281, 381, 400, 407, 434, 523, 530, 581, 633, 661, 748, 755, 771, 778, 863, 878, 928, 952]

# %%
# tedious with the commas - remove ? 
print(*positions)
# Out:
# 2 47 124 131 149 180 220 281 381 400 407 434 523 530 581 633 661 748 755 771 778 863 878 928 952
