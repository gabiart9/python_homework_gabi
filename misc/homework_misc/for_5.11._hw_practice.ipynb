# %% [markdown]
# # 2. Variables and Assignment

# %% [markdown]
# ## - Software Carpentry

# %%
age = 42
first_name = 'Ahmed'

# %%
print(first_name, "is", age, "years old")
# Out:
# Ahmed is 42 years old

# %%
last_name = "Francis"

# %%
print(first_name, last_name, "is", age, "years old")
# Out:
# Ahmed Francis is 42 years old

# %%
age = age + 3
print("Age in three years:", age)
# Out:
# Age in three years: 45

# %%
x = 5 
x += 3
print(x)
# Out:
# 8

# %% [markdown]
# ### Rosalind: INI2

# %%
c = (904**2 + 989**2)
print(c)
# Out:
# 1795337

# %% [markdown]
# = correct

# %% [markdown]
# ### w3 schools tests transcript:

# %% [markdown]
# <ins>python - variable</ins>

# %% [markdown]
# python variable: x = 5

# %% [markdown]
# x = "John"
# is the same as
# x = 'John'
# = true

# %% [markdown]
# a = 5
# is NOT the same as
# A = 5

# %% [markdown]
# print the data type of a variable: print(type(myvar))

# %% [markdown]
# <ins>python - variable names</ins>

# %% [markdown]
# not a leagal variable name: my-var = 20

# %% [markdown]
# possible names: my_var OR Myvar OR _myvar = 20

# %% [markdown]
# Create variable named carname and assign the value Volvo to it: carname = "Volvo"

# %% [markdown]
# Create a variable named x and assign the value 50 to it: x = 50

# %% [markdown]
# <ins>python - multiple variable values</ins>

# %% [markdown]
# add the value 'Hello World', to 3 variables in one statement: x = y = z = "Hello World"

# %% [markdown]
# assign values to multiple variables in one line: x , y , z = "Orange", "Banana", "Cherry"

# %% [markdown]
# Consider the following code:
# fruits = ['apple', 'banana', 'cherry']
# a, b, c = fruits
# print(a) -> result: apple

# %% [markdown]
# <ins>python - output variable</ins>

# %% [markdown]
# print('Hello', 'World')
# What will be the printed result?
# = Hello World

# %% [markdown]
# a = 'Hello'
# b = 'World'
# print(a + b)
# What will be the printed result?
# = HelloWorld

# %% [markdown]
# a = 4
# b = 5
# print(a + b)
# What will be the printed result?
# = 9

# %% [markdown]
# ### challenges carpentries

# %%
x = 5
x += 3
print(x)
# Out:
# 8

# %%
print(10 __ 5)
# Out:
#   Cell In[15], line 1
#     print(10 __ 5)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(10 * 5)
# Out:
# 50
