# %% [markdown]
# # dictionaries

# %% [markdown]
# key1 --> value 1
# key2 --> value 2

# %% [markdown]
# curly brackets to define dictionary

# %% [markdown]
# key : value
# values seperated by comma

# %% [markdown]
# dictionaries are mutable (just like lists)

# %% [markdown]
# copy better item by item

# %% [markdown]
# with len(dictionary) = number of pairs

# %% [markdown]
# deleting things from dictionary: statement: del dictionary["key"]

# %% [markdown]
# sort keys ?
# dictionary.keys()
# dictionary.values()
# type(dictionary.values())
# list(dictionary.values())
# dictionary.items() = gives all the pairs
# shopping_keys = list(dictionary.keys())
# shopping_keys ----> now sorted keys of dictionary

# %% [markdown]
# we can have lists inside dictionaries

# %% [markdown]
# values are lists - dictionary in dictionary are possible

# %% [markdown]
# ## 7) carpentries dictionaries excercises:

# %%
grades = {'Juan': {'Maths': 2},
          'John': {'History': 1, 'Biology': 3},
          'Gianni': {'Biology': 1}}

grades['Juan']['History'] = 2
grades['Juan']['Biology'] = 1

grades['John']['Maths'] = 1

grades['Gianni']['History'] = 4
grades['Gianni']['Maths'] = 3

print(grades)
# Out:
# {'Juan': {'Maths': 2, 'History': 2, 'Biology': 1}, 'John': {'History': 1, 'Biology': 3, 'Maths': 1}, 'Gianni': {'Biology': 1, 'History': 4, 'Maths': 3}}

# %% [markdown]
# # loops

# %%
for number in [1, 2 ,3, 4, 5]:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for number in [123, 52, 38, 41, 50]:
    print(number)
# Out:
# 123
# 52
# 38
# 41
# 50

# %%
for number in [123, 52, 38, 41, 50]:
    print(number)
    double = number * 2
    print(double)
# Out:
# 123
# 246
# 52
# 104
# 38
# 76
# 41
# 82
# 50
# 100

# %%
for number in [123, 52, 38, 41, 50]:
    double = number * 2
    print(number, double)

    print('loop finished')
# Out:
# 123 246
# loop finished
# 52 104
# loop finished
# 38 76
# loop finished
# 41 82
# loop finished
# 50 100
# loop finished

# %%
for number in [123, 52, 38, 41, 50]:
    double = number * 2
    print(number, double)

print('loop finished')
# Out:
# 123 246
# 52 104
# 38 76
# 41 82
# 50 100
# loop finished

# %%
s = "the quick brown fox jumps over the lazy dog"
for character in s:
    print(character)
# Out:
# t
# h
# e
#
# q
# u
# i
# c
# k
#
# b
# r
# o
# w
# n
#
# f
# o
# x
#
# j
# u
# m
# p
# s
#
# o
# v
# e
# r
#
# t
# h
# e
#
# l
# a
# z
# y
#
# d
# o
# g

# %%
s = "the quick brown fox jumps over the lazy dog"
for words in s.split():
    print(words)
# Out:
# the
# quick
# brown
# fox
# jumps
# over
# the
# lazy
# dog

# %%
s.split()
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
placeholder= 'x' * 6
for character in placeholder:
    print("HELP")
# Out:
# HELP
# HELP
# HELP
# HELP
# HELP
# HELP

# %%
for i in range(9):
    print(i, "HELP")
# Out:
# 0 HELP
# 1 HELP
# 2 HELP
# 3 HELP
# 4 HELP
# 5 HELP
# 6 HELP
# 7 HELP
# 8 HELP

# %% [markdown]
# i just to see where help is
# normally gootd for big numbers lik 150 or so

# %%
for i in range(9):
    print("HELP")
# Out:
# HELP
# HELP
# HELP
# HELP
# HELP
# HELP
# HELP
# HELP
# HELP

# %%
shopping = ["bread", "milk", "cheese"]
times = [1, 4, 10]
market = ["oefferl", "billa", "hofer"]

# %% [markdown]
# now 3 list to go over - so far only looped over 1 list

# %%
for i in range(3):
    print("buy", shopping[i], times[i], "times in", market[i])
# Out:
# buy bread 1 times in oefferl
# buy milk 4 times in billa
# buy cheese 10 times in hofer

# %%
for i in range(len(shopping)):
    print("buy", shopping[i], times[i], "times in", market[i])
# Out:
# buy bread 1 times in oefferl
# buy milk 4 times in billa
# buy cheese 10 times in hofer

# %%
for i, item in enumerate(shopping):
    print(i, item)
# Out:
# 0 bread
# 1 milk
# 2 cheese

# %%
for i, item in enumerate(shopping):
    print("buy", item, times[i], "times in", market[i])
# Out:
# buy bread 1 times in oefferl
# buy milk 4 times in billa
# buy cheese 10 times in hofer
