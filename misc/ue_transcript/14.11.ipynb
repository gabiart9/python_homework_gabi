# %% [markdown]
# setting variable before code

# %%
i = 0 
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 973 
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## initializing challenge: conditionals chapter

# %% [markdown]
# python allows you to initialize values in groups:

# %%
a, b, c = 0, 3, 5
print(a, b, c)
# Out:
# 0 3 5

# %% [markdown]
# = commata means its a group of things - on other side of = has to be same leng th of group

# %%
values = [...some test data...]
smallest = None
largest = None
for v in values:
    if ____:
        smallest, largest = v, v
    ____:
        smallest = min(____, v)
        largest = max(____, v)
print(smallest, largest)
# Out:
#   Cell In[7], line 1
#     values = [...some test data...]
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
help(min)
# Out:
# Help on built-in function min in module builtins:
#
# min(...)
#     min(iterable, *[, default=obj, key=func]) -> value
#     min(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its smallest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more positional arguments, return the smallest argument.

# %%
min(15, 10)
# Out:
# 10

# %%
min(-16, 6, 10)
# Out:
# -16

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more positional arguments, return the largest argument.

# %%
max(15, 10)
# Out:
# 15

# %%
max(-15,7,8,200)
# Out:
# 200

# %% [markdown]
# we dont use = to check for none
#
# we use is None instead of == None

# %%
values = [-3, 4, 8, 10, 88]
smallest, largest = None, None
for v in values:
    if smallest is None and largest is None:
        smallest, largest = v, v
    else:
        smallest = min(smallest, v)
        largest = max(largest, v)
print(smallest, largest)
# Out:
# -3 88

# %%
values = [-7.99, 8, 99]
smallest, largest = None, None
for v in values:
    if smallest is None and largest is None:
        smallest, largest = v, v
    else:
        smallest = min(smallest, v)
        largest = max(largest, v)
print(smallest, largest)
# Out:
# -7.99 99

# %%
values = [1, 1, 1]
smallest, largest = None, None
for v in values:
    if smallest is None and largest is None:
        smallest, largest = v, v
    else:
        smallest = min(smallest, v)
        largest = max(largest, v)
print(smallest, largest)
# Out:
# 1 1

# %% [markdown]
# # reading files into a list of lines
# we will need to read lots of files for rosalind & advent of code..
# here is how to do it

# %%
file_path = "/Users/gabia/Desktop/rosalind_ini6.txt"

# %%
lines = []
with open(file_path, 'r') as infile:
    for line in infile.readlines():
        cleaned = line.rstrip()
        lines.append(cleaned)

# %% [markdown]
# .strip = removes empty stufff ???

# %%
lines
# Out:
# ['When I find myself in times of trouble Mother Mary comes to me Speaking words of wisdom let it be And in my hour of darkness she is standing right in front of me Speaking words of wisdom let it be Let it be let it be let it be let it be Whisper words of wisdom let it be And when the broken hearted people living in the world agree There will be an answer let it be For though they may be parted there is still a chance that they will see There will be an answer let it be Let it be let it be let it be let it be There will be an answer let it be Let it be let it be let it be let it be Whisper words of wisdom let it be Let it be let it be let it be let it be Whisper words of wisdom let it be And when the night is cloudy there is still a light that shines on me Shine until tomorrow let it be I wake up to the sound of music Mother Mary comes to me Speaking words of wisdom let it be Let it be let it be let it be yeah let it be There will be an answer let it be Let it be let it be let it be 
# ...

# %% [markdown]
# variables inside a function only exist inside funktion so it can#t be called outside of the function

# %% [markdown]
# # new launcher - utilities - models - paste new file reader into it
# needs to be in the same directory as the notebooks that we are gonna use it in - then we can import the module "util"
# with util.name(filename) it can recall the function and use it

# %% [markdown]
# operation for advent of code make it into function to have it

# %% [markdown]
# filehandle opens when python deals with files

# %% [markdown]
# lists are not mutable and dictionaries are mutable
# if function does something with a list we have to be carefull cause it will alter the list itself
