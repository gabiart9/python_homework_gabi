# %% [markdown]
# blah blah

# %%
name[len(name) - 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name[len(name) - 1]
#
# NameError: name 'name' is not defined

# %%
len(name) - 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 len(name) - 1
#
# NameError: name 'name' is not defined

# %% [markdown]
# how long is the stiring - position

# %%
name = "the string is alpha"
name[len(name) - 1]
# Out:
# 'a'

# %%
len(name)
# Out:
# 19

# %%
name[0]
# Out:
# 't'

# %%
last_position = 20 #21st character

# %%
name[last_position]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 name[last_position]
#
# IndexError: string index out of range

# %% [markdown]
# screen shot !! - problem question of chapter 4 carpentries

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# # transcript of lecture:

# %% [markdown]
# carpentries chapter 6:

# %%
s = "The quick brown fox jumps over the lazy dog"

# %%
s.split()
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
type(s.split())
# Out:
# list

# %% [markdown]
# list = set of valiues (strings or numbers or objects) in a specific order

# %%
shopping = ["bread", "potatoes", "eggs", "flour", "rubber duck", "pizza", "milk"]

# %%
shopping
# Out:
# ['bread', 'potatoes', 'eggs', 'flour', 'rubber duck', 'pizza', 'milk']

# %%
shopping.upper
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 shopping.upper
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
shopping.sort()

# %%
shopping
# Out:
# ['bread', 'eggs', 'flour', 'milk', 'pizza', 'potatoes', 'rubber duck']

# %% [markdown]
# = alphabetically sorted

# %%
shopping.append("cheese")

# %%
shopping
# Out:
# ['bread',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck',
#  'cheese']

# %%
shopping.sort()

# %%
shopping
# Out:
# ['bread',
#  'cheese',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck']

# %%
#cheese is important - should be at top

# %%
shopping.insert(0, "cheese!")

# %%
shopping
# Out:
# ['cheese!',
#  'bread',
#  'cheese',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck']

# %%
shopping.pop()
# Out:
# 'rubber duck'

# %%
shopping
# Out:
# ['cheese!', 'bread', 'cheese', 'eggs', 'flour', 'milk', 'pizza', 'potatoes']

# %%
shopping.pop(2)
# Out:
# 'cheese'

# %%
shopping
# Out:
# ['cheese!', 'bread', 'eggs', 'flour', 'milk', 'pizza', 'potatoes']

# %%
shopping.append("rubber duck")

# %%
shopping
# Out:
# ['cheese!',
#  'bread',
#  'eggs',
#  'flour',
#  'milk',
#  'pizza',
#  'potatoes',
#  'rubber duck']

# %%
shopping.pop(2)
# Out:
# 'eggs'

# %%
shopping
# Out:
# ['cheese!', 'bread', 'flour', 'milk', 'pizza', 'potatoes', 'rubber duck']

# %%
words = s.split()

# %%
help(str.strip)
# Out:
# Help on method descriptor strip:
#
# strip(self, chars=None, /) unbound builtins.str method
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
"cheese".strip("e")
# Out:
# 'chees'

# %% [markdown]
# strip not possible on list  :(

# %% [markdown]
# lists vs string vs numbers:

# %%
s
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
words = s.split()

# %%
s[-3]
# Out:
# 'd'

# %%
s.split()
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
# 2nd letter of 4th word

# %%
words
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
words[3]
# Out:
# 'fox'

# %%
words[3][1]
# Out:
# 'o'

# %%
to_do = s.split()

# %%
to_do.pop(2)
# Out:
# 'brown'

# %% [markdown]
# ## chapter 6

# %%
pressures = [0.273, 0.275, 0.277, 0.275, 0.276]
print('pressures:', pressures)
print('length:', len(pressures))
# Out:
# pressures: [0.273, 0.275, 0.277, 0.275, 0.276]
# length: 5

# %%
print('zeroth item of pressures:', pressures[0])
print('fourth item of pressures:', pressures[4])
# Out:
# zeroth item of pressures: 0.273
# fourth item of pressures: 0.276

# %%
'fourth item of pressures:', pressures[4]
# Out:
# ('fourth item of pressures:', 0.276)

# %%
pressures[0] = 0.265
print('pressures is now:', pressures)
# Out:
# pressures is now: [0.265, 0.275, 0.277, 0.275, 0.276]

# %%
primes = [2, 3, 5]
print('primes is initially:', primes)
primes.append(7)
print('primes has become:', primes)
# Out:
# primes is initially: [2, 3, 5]
# primes has become: [2, 3, 5, 7]

# %%
teen_primes = [11, 13, 17, 19]
middle_aged_primes = [37, 41, 43, 47]
print('primes is currently:', primes)
primes.extend(teen_primes)
print('primes has now become:', primes)
primes.append(middle_aged_primes)
print('primes has finally become:', primes)
# Out:
# primes is currently: [2, 3, 5, 7]
# primes has now become: [2, 3, 5, 7, 11, 13, 17, 19]
# primes has finally become: [2, 3, 5, 7, 11, 13, 17, 19, [37, 41, 43, 47]]

# %% [markdown]
# trying that on my own:

# %%
jam = ["straberry", "peanut", "apple"]
print("beginner jams:", jam)
difficult_jams = ["melon", "pear", "nut"]
jam.extend(difficult_jams)
print("more complex jams:", jam)
hardcore_jams = ["onion", "caramel_banana", "cucumber"]
jam.extend(hardcore_jams)
print("gourmet jams:", jam)
# Out:
# beginner jams: ['straberry', 'peanut', 'apple']
# more complex jams: ['straberry', 'peanut', 'apple', 'melon', 'pear', 'nut']
# gourmet jams: ['straberry', 'peanut', 'apple', 'melon', 'pear', 'nut', 'onion', 'caramel_banana', 'cucumber']

# %%
primes = [2, 3, 5, 7, 9]
print('primes before removing last item:', primes)
del primes[4]
print('primes after removing last item:', primes)
# Out:
# primes before removing last item: [2, 3, 5, 7, 9]
# primes after removing last item: [2, 3, 5, 7]

# %%
shopping
# Out:
# ['cheese!', 'bread', 'flour', 'milk', 'pizza', 'potatoes', 'rubber duck']

# %%
del shopping[2]
shopping
# Out:
# ['cheese!', 'bread', 'rubber duck']

# %%
shopping=['cheese!', 'bread', 'flour', 'milk', 'pizza', 'potatoes', 'rubber duck']

# %%
shopping
# Out:
# ['cheese!', 'bread', 'flour', 'milk', 'pizza', 'potatoes', 'rubber duck']

# %%
del shopping[2]

# %%
shopping
# Out:
# ['cheese!', 'bread', 'potatoes', 'rubber duck']

# %%
goals = [1, 'Create lists.', 2, 'Extract items from lists.', 3, 'Modify lists.']

# %%
print(goals)
# Out:
# [1, 'Create lists.', 2, 'Extract items from lists.', 3, 'Modify lists.']

# %%
element = 'carbon'
print('zeroth character:', element[0])
print('third character:', element[3])
# Out:
# zeroth character: c
# third character: b

# %%
dogs = "pitbull terrier"
print("b:", dogs[3])
print("rr:", dogs[10], dogs[11])
# Out:
# b: b
# rr: r r

# %%
element[0] = 'C'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 element[0] = 'C'
#
# TypeError: 'str' object does not support item assignment

# %%
values = []
values.append(1)
values.append(3)
values.append(5)
print('first time:', values)
values = values[1:]
print('second time:', values)
# Out:
# first time: [1, 3, 5]
# second time: [3, 5]

# %% [markdown]
# values = values[1:] because 1 is in position 0 not 1 therefore it starts with 3 aka 1. position

# %%
print('string to list:', list('tin'))
print('list to string:', ''.join(['g', 'o', 'l', 'd']))
# Out:
# string to list: ['t', 'i', 'n']
# list to string: gold

# %%
print("_".join(["yellow", "fish", "of", "the", "ocean"]))
# Out:
# yellow_fish_of_the_ocean

# %%
print("song:", list("ApppleBottomJeans"))
# Out:
# song: ['A', 'p', 'p', 'p', 'l', 'e', 'B', 'o', 't', 't', 'o', 'm', 'J', 'e', 'a', 'n', 's']

# %%
"Appple-Bottom-Jeans".split("-")
# Out:
# ['Appple', 'Bottom', 'Jeans']

# %%
print("song:", list("Appple,Bottom,Jeans"))
# Out:
# song: ['A', 'p', 'p', 'p', 'l', 'e', ',', 'B', 'o', 't', 't', 'o', 'm', ',', 'J', 'e', 'a', 'n', 's']

# %%
element = 'helium'
print(element[-1])
# Out:
# m

# %%
print(element[-2])
# Out:
# u

# %%
element = 'fluorine'
print(element[::2])
print(element[::-1])
# Out:
# furn
# eniroulf
