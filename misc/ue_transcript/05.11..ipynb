# %% [markdown]
# ### from last time ^operator

# %%
8^3
# Out:
# 11

# %% [markdown]
# ## class notes

# %%
b = 4
print(type(b))
# Out:
# <class 'int'>

# %%
a = 578
print(type(a))
# Out:
# <class 'int'>

# %%
c = 5,89
print(type(c))
# Out:
# <class 'tuple'>

# %%
d = 4,5
print(type(d))
# Out:
# <class 'tuple'>

# %%
d = 4.5
print(type(d))
# Out:
# <class 'float'>

# %%
print(type(5-3))
# Out:
# <class 'int'>

# %%
print(type('hello' - 'h'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(type('hello' - 'h'))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# - error message - type error - used stuff in wrong place -python only reports 1 error - traceback: shows line where error occour
# - minus is not sutable for string and string

# %%
print(type('hello' + 'h'))
# Out:
# <class 'str'>

# %%
print(type('hello' * 'h'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(type('hello' * 'h'))
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print(type('hello' * 6))
# Out:
# <class 'str'>

# %%
some_long_string = "the quick brown fox jumps over the lazy dog"

# %%
len(some_long_string)
# Out:
# 43

# %% [markdown]
# len = length

# %%
some_long_string[0:4]
# Out:
# 'the '

# %% [markdown]
# numbers dont have lengths but strings and many other things do

# %%
len(1992)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 len(1992)
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# counting digits:

# %%
len(str(1992))
# Out:
# 4

# %%
len("1992")
# Out:
# 4

# %%
some_number = "76"

# %%
1 + some_number
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 1 + some_number
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
1 + int(some_number)
# Out:
# 77

# %%
another_number = "76.8"

# %%
1 + int(another_number)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 1 + int(another_number)
#
# ValueError: invalid literal for int() with base 10: '76.8'

# %%
1 + float(another_number)
# Out:
# 77.8

# %% [markdown]
# = does only work with float cause 76,8 is not an integer but a float

# %% [markdown]
# ## functions:

# %%
"test test".upper()
# Out:
# 'TEST TEST'

# %%
len("test")
# Out:
# 4

# %%
test = print ("bla bla")
# Out:
# bla bla

# %%
type(test)
# Out:
# NoneType

# %%
test = "test test test test"
test.replace("e", "a")
# Out:
# 'tast tast tast tast'

# %%
test.count("s")
# Out:
# 4

# %% [markdown]
# ### Rosalind: counting DNA nucleotides

# %%
s = "..."

# %%
count_A = s.count("A")
count_C = s.count("C")
count_G = s.count("G")
count_T = s.count("T")

# %%
print(count_A, count_C, count_G, count_T)
# Out:
# 240 226 254 211

# %% [markdown]
# ### Rosalind: Transcribing DNA into RNA

# %%
j = "..."

# %%
print(j.replace("T", "U"))
# Out:
# ...
