# %% [markdown]
# # counting DNA nucleotides via dictionary

# %%
DNA = "..."

# %%
count = {
    "A": DNA.count("A"),
    "C": DNA.count("C"),
    "G": DNA.count("G"),
    "T": DNA.count("T"),
}
print(count)
# Out:
# {'A': 240, 'C': 226, 'G': 254, 'T': 211}
