# %% [markdown]
# # Day 4 - testing

# %% [markdown]
# input =
#     ..@@.@@@@.
#     @@@.@.@.@@
#     @@@@@.@.@@
#     @.@@@@..@.
#     @@.@@@@.@@
#     .@@@@@@@.@
#     .@.@.@.@@@
#     @.@@@.@@@@
#     .@@@@@@@@.
#     @.@.@@@.@.

# %% [markdown]
# @ = rolls of paper
# only access a roll if <4 rolls of paper in 8 adjacent positions
# !!! adjacent = every direction = also diagonal !!!

# %% [markdown]
# #### 13 rolls accessable (marked with x):
#     ..xx.xx@x.
#     x@@.@.@.@@
#     @@@@@.x.@@
#     @.@@@@..@.
#     x@.@@@@.@x
#     .@@@@@@@.@
#     .@.@.@.@@@
#     x.@@@.@@@@
#     .@@@@@@@@.
#     x.x.@@@.x.

# %% [markdown]
# #### wanted:
# number of accessable paper rolls
# -> count
