# %% [markdown]
# # day 5:

# %% [markdown]
# 1) read file into lines -> seperate input data through empty file
# 2) read ranges into dictionary
# 3) read IDs into ID List
# 4) for loop ID in ranges (key + value dic) if == than new variable +1

# %% [markdown]
# test _ranges =
# 3-5
# 10-14
# 16-20
# 12-18
#
# test_ID =
# 1
# 5
# 8
# 11
# 17
# 32

# %%
test_ranges_dic = {
    3 : 5,
    10 : 14,
    16 : 20, 
    12 : 18
}

test_ID = [1, 5, 8, 11, 17, 32]

# %%
count_fresh_ID = 0

# %%
print(test_ranges_dic.keys())
print(test_ranges_dic.values())
# Out:
# dict_keys([3, 10, 16, 12])
# dict_values([5, 14, 20, 18])

# %%
# playing with only one fresh ID & range for testing
simple_range = {
        3:5
}
simple_ID = [4] 
simple_count = 0

for x in simple_ID:
        for key, value in simple_range.items():
            if x >= key and x <= value:
                simple_count += 1

        print(simple_count)
# Out:
# 1

# %%
def fresh_ingredients(simple_ID, simple_range):
    simple_count = 0
    id_long = []
    for x in simple_ID:
        for key, value in simple_range.items():
            if x >= key and x <= value:
                id_long.append = x

    
    
    return simple_count

# %%
test_ranges_dic = {
    3 : 5,
    10 : 14,
    16 : 20, 
    12 : 18
}

test_ID = [1, 5, 8, 11, 17, 32]

fresh_ingredients(test_ID, test_ranges_dic)
# Out:
# 4
