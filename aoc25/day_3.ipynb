# %% [markdown]
# # day 3:

# %%
# def function to read txt file into lines 
def read_file_into_lines(file_path):
    lines = []
    with open(file_path, 'r') as infile:
        for line in infile.readlines():
            cleaned = line.rstrip()
            lines.append(cleaned)
    return lines

# %%
data = read_file_into_lines("C:/Users/gabia/Desktop/python_homework_gabi/data/advent_of_code_3.1.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = read_file_into_lines("C:/Users/gabia/Desktop/python_homework_gabi/data/advent_of_code_3.1.txt")
#
# Cell In[3], line 4, in read_file_into_lines(file_path)
#       2 def read_file_into_lines(file_path):
#       3     lines = []
# ----> 4     with open(file_path, 'r') as infile:
#       5         for line in infile.readlines():
#       6             cleaned = line.rstrip()
#
# File ~\miniforge3\envs\carpentries\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/gabia/Desktop/python_homework_gabi/data/advent_of_code_3.1.txt'

# %%
def max_joltage(s): 
    max_sofar_1 = 0
    max_index_1 = 0
    
    #first max:
    for i, x in enumerate(s[:-1]): 
        if int(x) > max_sofar_1: 
            max_sofar_1 = int(x)
            max_index_1 = i  

    # second max: 
    max_sofar_2 = 0
    for i, x in enumerate(s[max_index_1 + 1:]): 
        if int(x) > max_sofar_2: 
            max_sofar_2 = int(x) 
    
    # give combined number of both max:
    return int(str(max_sofar_1)+(str(max_sofar_2)))

# %%
final_numbers = []
number = 0 

for x in data: 
    number = max_joltage(x)
    final_numbers.append(number)
print(sum(final_numbers))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 final_numbers = []
#       2 number = 0
# ----> 4 for x in data:
#       5     number = max_joltage(x)
#       6     final_numbers.append(number)
#
# NameError: name 'data' is not defined
