# %% [markdown]
# # day 3:

# %% [markdown]
# 1) Txt into list
# [ ]
# 2) find 1. & 2. max numer in every list item
# [ ]
# 3) make max joltage numver out of those (in correct order)
# [ ]
# 4) ads max joltage togetehr - SUM
# [ ]

# %%
# def function to read txt file into lines 
def read_file_into_lines(file_path):
    lines = []
    with open(file_path, 'r') as infile:
        for line in infile.readlines():
            cleaned = line.rstrip()
            lines.append(cleaned)
    return lines

# %%
# 1) make list of data 
# instructions = read_file_into_lines("C:/Users/gabia/Desktop/python_homework_gabi/data/advent_of_code_3.1.txt")

# %%
example_data = ['987654321111111', '811111111111119', '234234234234278', '818181911112111']

# %%
# for loop to go over every item and find 1. max 
# then save it in new variable in a new list
# delete that and go over again to find second max
# add second max to variable 
#

# %%
one_line = '987654321111111'

# %%
    max_sofar_1 = 0
    max_index_1 = 0
    numbers_list = []
    for i, x in enumerate(one_line[:-1]): 
        if int(x) > max_sofar_1: 
            max_sofar_1 = int(x)
            max_index_1 = i  
    
    max_sofar_2 = 0
    max_index_2 = 0
    for i, x in enumerate(one_line[max_index + 1:]): 
        if int(x) > max_sofar_2: 
            max_sofar_2 = int(x) 
    
    full_numbers = (str(max_sofar_1))+(str(max_sofar_2))
    numbers_list.append(full_numbers)
    
    print(numbers_list)
# Out:
# ['98']

# %%
def max_joltage(s):
# Out:
#   Cell In[57], line 1
#     def max_joltage(s):
#                         ^
# _IncompleteInputError: incomplete input
